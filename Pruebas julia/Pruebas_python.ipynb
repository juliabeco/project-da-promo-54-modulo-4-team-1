# %%
import matplotlib.pyplot as plt
import numpy as np

# idea original de https://www.kaggle.com/code/joshuaswords/netflix-data-visualization
# Modificación para incluir generaciones

# Datos de generaciones
generaciones = [
    ("Generación Silenciosa", 1928, 1945),
    ("Baby Boomers", 1946, 1964),
    ("Generación X", 1965, 1980),
    ("Millennials", 1981, 1996),
    ("Generación Z", 1997, 2012),
    ("Generación Alfa", 2013, 2025)
]

year_now = 2025
edades = [(year_now - fin, year_now - inicio) for _, inicio, fin in generaciones]

# Configurar figura
fig, ax = plt.subplots(figsize=(15, 4), constrained_layout=True)
ax.set_ylim(-2, 2)
ax.set_xlim(1900, 2030)

# Línea base
ax.axhline(0, xmin=0.02, xmax=0.98, color="#4a4a4a", lw=2, zorder=1)

# Función para color según generación
def color_gen(nombre):
    if nombre in ["Baby Boomers", "Millennials"]:
        return "#007ACC"  # azul
    else:
        return "#A0A0A0"  # gris

# Dibujar puntos, líneas y textos
for (nombre, inicio, fin), (edad_min, edad_max) in zip(generaciones, edades):
    color = color_gen(nombre)
    z = 5 if nombre in ["Baby Boomers", "Millennials"] else 3

    # Línea del periodo
    ax.plot([inicio, fin], [0, 0], color=color, lw=4, zorder=z)

    # Círculos
    ax.scatter([inicio, fin], [0, 0], s=140, color=color, zorder=z + 1)
    ax.scatter([inicio, fin], [0, 0], s=45, color="white", zorder=z + 2)

    # Líneas verticales con el año
    for x, pos in zip([inicio, fin], ["up", "down"]):
        ax.plot([x, x], [0, -0.25 if pos == "down" else 0.25], color=color, lw=1.5, zorder=z + 3)
        ax.text(x, -0.4 if pos == "down" else 0.35, str(x), ha='center',
                fontsize=9, color=color, fontweight='bold')

    # Texto de generación
    if nombre in ["Baby Boomers", "Millennials"]:
        ax.text((inicio + fin) / 2, 0.75, nombre, ha='center', va='bottom',
                fontsize=12, fontweight='bold', color=color)
        ax.text((inicio + fin) / 2, 0.45, f"Edad 2025: {edad_min}-{edad_max}",
                ha='center', va='bottom', fontsize=9, color='dimgray')
    else:
        ax.text((inicio + fin) / 2, -0.7, nombre, ha='center',
                fontsize=10, fontweight='bold', color=color)
        ax.text((inicio + fin) / 2, -1.0, f"Edad 2025: {edad_min}-{edad_max}",
                ha='center', fontsize=8, color='dimgray')

# --- Títulos ---
ax.text(1965, 1.6, "Línea de tiempo generacional (1900–2025)",
        fontsize=16, fontweight='bold', color="#333333", ha='center')
ax.text(1965, 1.25, "Comparación de generaciones: Baby Boomers vs Millennials",
        fontsize=13, fontweight='bold', color="#007ACC", ha='center')

# Limpieza visual
ax.set_xticks([])  # quitar eje X
ax.set_yticks([])
for spine in ["left", "top", "right", "bottom"]:
    ax.spines[spine].set_visible(False)

plt.show()

# %% [markdown]
# 💡 Propuesta 1: “Dos caminos, un mismo sueño: el acceso a la vivienda entre Baby Boomers y Millennials”
#
# Idea central:
# Explorar cómo las condiciones económicas, laborales y educativas han afectado el acceso a la vivienda en ambas generaciones.
#
# Storytelling:
#
# Introducción: contextualizar la importancia del acceso a la vivienda como indicador de bienestar.
#
# Comparar Baby Boomers y Millennials según:
#
# Ingreso promedio.
#
# Nivel educativo.
#
# Tipo de empleo y estabilidad laboral.
#
# Mostrar cómo esas diferencias se traducen en capacidad de ahorro o compra (puedes estimarlo a partir de los ingresos en adult.csv + salarios medios del Excel).
#
# Final: sugerir políticas públicas o tendencias de mercado (por ejemplo, auge del alquiler o co-living).
#
# Visualizaciones sugeridas:
#
# Línea de tiempo (como la que hiciste).
#
# Boxplot comparando ingresos por generación.
#
# Gráfico de barras apiladas de niveles educativos.
#
# Sankey o treemap de tipos de empleo.
#
# Mapa de calor de ingreso vs educación vs horas trabajadas.
#
# Impacto: Muestra desigualdades generacionales reales y genera debate social.
#
# 💡 Propuesta 2: “El valor del trabajo: ¿quién se beneficia más del esfuerzo?”
#
# Idea central:
# Analizar la relación entre horas trabajadas, nivel educativo e ingresos entre ambas generaciones.
#
# Storytelling:
#
# Introducir el mito del “trabajo duro” como garantía de éxito.
#
# Mostrar datos: los Boomers trabajaban más horas en promedio, pero con mejores salarios; los Millennials tienen más educación pero menor recompensa.
#
# Analizar brechas por sector laboral o género.
#
# Conclusión: la educación ya no garantiza ascenso económico como antes.
#
# Visualizaciones sugeridas:
#
# Scatter plot (horas trabajadas vs ingreso).
#
# Barras comparativas de nivel educativo vs ingreso por generación.
#
# Heatmap de ocupación y salario.
#
# KPI dinámico con salario medio ajustado por horas.
#
# Impacto: Cuestiona el paradigma del mérito y refleja la evolución del mercado laboral.
#
# 💡 Propuesta 3: “La revolución educativa: cómo cambió el retorno de la educación en dos generaciones”
#
# Idea central:
# Mostrar cómo la relación entre educación e ingreso ha cambiado entre Boomers y Millennials.
#
# Storytelling:
#
# Presentar la educación como motor del progreso económico.
#
# Comparar distribución de niveles educativos.
#
# Evaluar la relación entre educación e ingreso en cada generación.
#
# Mostrar cómo la brecha salarial se redujo (o no) entre niveles.
#
# Conclusión: ¿la inversión educativa sigue valiendo lo mismo?
#
# Visualizaciones sugeridas:
#
# Barras de niveles educativos (comparativas).
#
# Diagrama de dispersión ingreso vs educación por generación.
#
# Gráfico de línea de “retorno educativo” (pendiente del ingreso por nivel educativo).
#
# Dashboard con KPIs educativos.
#
# Impacto: Muy útil si quieres resaltar análisis multivariable y técnicas estadísticas.
#
# 💡 Propuesta 4: “Dos mundos laborales: sectores, salarios y estabilidad entre generaciones”
#
# Idea central:
# Explorar cómo los sectores económicos y ocupaciones más frecuentes difieren entre generaciones, y qué implicancias tienen en sus ingresos y calidad de vida.
#
# Storytelling:
#
# Describir cómo cambió el mercado laboral: manufactura vs tecnología, trabajo estable vs freelance.
#
# Identificar sectores dominantes por generación.
#
# Comparar ingreso promedio y horas trabajadas por sector.
#
# Concluir sobre la transformación del trabajo (automatización, digitalización, economía del conocimiento).
#
# Visualizaciones sugeridas:
#
# Barras o treemap por sector laboral.
#
# Gráfico de violín: ingreso por ocupación.
#
# Radar chart comparando skills dominantes.
#
# Timeline con evolución sectorial.
#
# Impacto: Ideal para audiencias empresariales o de recursos humanos.
#
# 💡 Propuesta 5: “El futuro del poder adquisitivo: una mirada generacional al ingreso y el consumo”
#
# Idea central:
# Analizar el poder adquisitivo y los patrones de gasto potencial entre generaciones, vinculando educación, horas trabajadas e ingresos.
#
# Storytelling:
#
# Introducir la idea del “consumo responsable” y cómo cambia con la edad.
#
# Calcular un índice de poder adquisitivo estimado (ingreso / horas trabajadas o ingreso ajustado por edad).
#
# Comparar hábitos de consumo potenciales por generación (puedes inferir con educación, edad y ocupación).
#
# Cierre: implicaciones para empresas que diseñan productos para diferentes públicos.
#
# Visualizaciones sugeridas:
#
# Bubble chart de ingreso vs edad vs horas trabajadas.
#
# KPI cards con poder adquisitivo promedio.
#
# Storyboard comparativo (Millennial vs Boomer).
#
# Segmentación visual tipo “buyer persona” por generación.
#
# Impacto: Potente si lo presentas como una herramienta estratégica para empresas o marketing generacional.

# %% [markdown]
# 💡 “Dos caminos, un mismo sueño: el acceso a la vivienda entre Baby Boomers y Millennials.”
#
# A continuación te detallo la estructura página por página, los elementos de diseño, gráficos sugeridos, y la narrativa visual paso a paso.
# 🎨 Diseño general y estilo visual
#
# Paleta de colores (moderna y emocional):
#
# Azul oscuro (#004C97): confianza, estabilidad (para los Baby Boomers).
#
# Celeste (#00AEEF): frescura, juventud (para los Millennials).
#
# Gris claro (#EAEAEA): fondo neutro.
#
# Blanco (#FFFFFF): fondo principal de las páginas.
#
# Toques de naranja suave (#FFA726): para destacar KPI o botones interactivos.
#
# Tipografía sugerida:
# Usar Montserrat o Segoe UI (limpia, moderna y legible).
#
# Estilo visual:
#
# Minimalista, con amplios espacios en blanco.
#
# Íconos vectoriales planos (hogar, trabajo, educación, ahorro, etc.).
#
# Gráficos con bordes suaves y tonos coherentes con la generación que representan.
#
# Uso de bookmarks y navegación personalizada para una experiencia interactiva tipo storytelling.
#
# 🏠 Página 1: Portada — “Dos caminos, un mismo sueño”
#
# Objetivo: causar impacto visual y contextualizar el tema.
#
# Contenido:
#
# Título principal (centrado):
# 👉 “Dos caminos, un mismo sueño: el acceso a la vivienda entre Baby Boomers y Millennials”
# En azul oscuro con una tipografía elegante.
#
# Subtítulo:
# Un análisis comparativo sobre las condiciones económicas, educativas y laborales que determinan el acceso a la vivienda.
#
# Imagen de fondo:
# Fotografía o ilustración sutil de una ciudad o dos casas conectadas por un camino (una más tradicional y otra moderna).
# Opacidad baja (20–30%) para no distraer del texto.
#
# Visual central animado:
# Tu línea de tiempo generacional (como la que ya creaste) con marcadas las dos generaciones principales.
# Esto introduce la historia visualmente.
#
# Botones de navegación:
# En la parte inferior, tipo menú horizontal:
#
# 📊 Panorama general
#
# 💼 Situación laboral
#
# 🎓 Educación e ingresos
#
# 🏡 Capacidad de acceso a vivienda
#
# 📈 Conclusiones y políticas
#
# 🧭 Volver al inicio
#
# (Cada botón con ícono y color correspondiente a su tema, usando bookmarks).
#
# 📊 Página 2: Panorama general — “Dos generaciones, dos contextos”
#
# Objetivo: presentar el contexto y las diferencias demográficas.
#
# Diseño y disposición:
#
# Encabezado con texto breve:
# “Antes de analizar la vivienda, veamos quiénes son realmente los Baby Boomers y los Millennials.”
#
# Visual 1:
# ➤ Segmentación dinámica con slicers (por generación).
#
# Edad promedio (2025), proporción hombres/mujeres.
#
# Distribución de población activa (mapa o barras).
#
# Visual 2:
# ➤ Línea de tiempo interactiva con los periodos de ambas generaciones.
#
# Visual 3:
# ➤ Tarjetas KPI comparativas:
#
# Edad media
#
# Ingreso medio
#
# Nivel educativo más frecuente
#
# % empleados a tiempo completo
#
# Elemento narrativo:
# Texto flotante tipo “insight box”:
#
# “Aunque los Baby Boomers crecieron en una era de estabilidad económica, los Millennials enfrentan un mercado laboral más competitivo y digitalizado.”
#
# 💼 Página 3: Situación laboral — “El trabajo, pilar del acceso a la vivienda”
#
# Objetivo: mostrar cómo las diferencias laborales afectan los ingresos y la estabilidad.
#
# Diseño y disposición:
#
# Visual 1 (izquierda):
# ➤ Treemap o barras apiladas con los principales sectores laborales por generación.
#
# Visual 2 (derecha):
# ➤ Boxplot o violín comparando distribución de ingresos por tipo de ocupación.
#
# Visual 3 (abajo):
# ➤ Heatmap (ingreso vs horas trabajadas vs tipo de empleo).
#
# Interactividad:
# Filtros para seleccionar género o educación.
#
# Insight narrativo:
#
# “Los Millennials, a pesar de tener mayor nivel educativo, tienden a trabajar en sectores más volátiles y con salarios iniciales más bajos.”
#
# 🎓 Página 4: Educación e ingresos — “¿Más educación, mejores oportunidades?”
#
# Objetivo: mostrar si la educación sigue siendo garantía de progreso económico.
#
# Diseño y disposición:
#
# Visual 1 (superior):
# ➤ Gráfico de barras horizontales mostrando la distribución de niveles educativos por generación.
#
# Visual 2 (inferior izquierda):
# ➤ Scatter plot de ingreso promedio vs nivel educativo (coloreado por generación).
#
# Visual 3 (inferior derecha):
# ➤ Línea o área mostrando el retorno educativo (pendiente del ingreso según nivel de estudios).
#
# Insight narrativo:
#
# “El retorno educativo es menor para los Millennials: los títulos universitarios ya no garantizan los mismos niveles de ingreso que hace 30 años.”
#
# 🏡 Página 5: Capacidad de acceso a la vivienda — “El sueño cada vez más lejano”
#
# Objetivo: unir todo: ingresos, horas trabajadas, educación y edad → capacidad de ahorro o compra.
#
# Diseño y disposición:
#
# Visual 1:
# ➤ Índice estimado de capacidad de compra (ingreso – costo de vida) → KPI principal.
#
# Visual 2:
# ➤ Gauge o termómetro comparativo entre generaciones.
#
# Visual 3:
# ➤ Mapa de calor o bubble chart mostrando relación entre ingreso y horas trabajadas, filtrable por educación.
#
# Visual 4:
# ➤ Infografía o icon cards con los principales hallazgos:
#
# % que podría comprar vivienda.
#
# % que alquila o vive con familia.
#
# Insight narrativo:
#
# “Los Baby Boomers necesitaban 5 años de salario para comprar su primera casa. Los Millennials, más de 10.”
#
# 📈 Página 6: Conclusiones y políticas — “Repensando el sueño de la casa propia”
#
# Objetivo: cerrar el storytelling con impacto social y propuestas.
#
# Diseño y disposición:
#
# Texto central breve: resumen de los hallazgos clave.
#
# Visual:
# ➤ Word cloud o infografía con las palabras clave de la historia (educación, deuda, estabilidad, ahorro, mercado).
#
# Visual complementario:
# ➤ Tabla resumen con métricas comparativas (Boomers vs Millennials).
#
# Cierre:
# Bloque tipo cita:
#
# “El acceso a la vivienda ya no depende solo del esfuerzo individual, sino del contexto económico y las oportunidades disponibles.”
#
# Botón final: 🔁 Volver al inicio.
#
# 💡 Aspectos técnicos que demostrarían tus skills
#
# Uso de modelado de datos (DAX) para crear medidas calculadas:
#
# “Ingreso promedio por generación”.
#
# “Capacidad de compra estimada”.
#
# “Retorno educativo”.
#
# Segmentadores personalizados (por género, educación, tipo de empleo).
#
# Botones con bookmarks y navegación personalizada.
#
# Uso de tooltips enriquecidos para mostrar detalles sin sobrecargar los gráficos.

# %%
# incluir una imagen en el jupyter notebook
from IPython.display import Image
Image("ejemplo_powerbi_proyecto4.png")

# %% [markdown]
# ## Ejemplo speech pagina 1 y 6
#
# 🎬 Página 1 — Portada: “Dos caminos, un mismo sueño”
#
# “Durante décadas, tener una vivienda propia fue sinónimo de éxito, estabilidad y futuro.
# Los Baby Boomers lo vivieron como un sueño alcanzable: con un empleo estable, podían comprar su casa antes de los 35 años. Pero los tiempos cambiaron.
# Hoy, los Millennials —a pesar de tener más estudios y estar más conectados que nunca— se enfrentan a un escenario donde los salarios crecen más lento que los precios de la vivienda, los alquileres se disparan y la estabilidad laboral es cada vez más incierta.
# En este informe vamos a recorrer, con datos, la historia de dos generaciones que crecieron bajo contextos muy distintos… pero con un mismo sueño: acceder a un hogar propio.”
#
# 🏁 Página final — Conclusiones y políticas públicas
#
# “Los datos nos muestran una realidad clara: el acceso a la vivienda se ha convertido en un lujo para gran parte de la generación Millennial.
# Mientras los Baby Boomers invirtieron cerca de 4 a 5 años de salario para comprar una casa, hoy esa cifra supera los 10 años en muchos países desarrollados. Además, los Millennials destinan más del 40% de su ingreso mensual al alquiler, lo que limita su capacidad de ahorro y de independencia económica.
#
# Frente a este panorama, las políticas públicas no pueden seguir siendo las mismas.
# Promover programas de acceso a crédito adaptados a los ingresos reales, fomentar la vivienda cooperativa, e incentivar modelos de alquiler social o co-living podrían ser pasos necesarios para equilibrar el terreno.
#
# Porque en definitiva, más que una cuestión económica, el derecho a una vivienda digna es una cuestión de equidad intergeneracional.”

# %%
# word cloud example
#%pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Educación Deuda Estabilidad Futuro Ingresos Vivienda 'Baby boomers' Millenials Posibilidades Generaciones Trabajo Cambios"
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text) #, colormap='Oranges'

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig("wordcloud_green.png", format="png")
plt.show()

# %% [markdown]
# de este link saque la de world population
# https://www.kaggle.com/datasets/whenamancodes/world-population-live-dataset

# %%
#importar un csv en pandas
import pandas as pd
df = pd.read_csv('world_population.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         233 non-null    object
#  1   Name                         234 non-null    object
#  2   2022                         234 non-null    int64
#  3   2020                         234 non-null    int64
#  4   2015                         234 non-null    int64
#  5   2010                         234 non-null    int64
#  6   2000                         234 non-null    int64
#  7   1990                         234 non-null    int64
#  8   1980                         234 non-null    int64
#  9   1970                         234 non-null    int64
#  10  Area (km²)                   234 non-null    int64
#  11  Density (per km²)            234 non-null    float64
#  12  GrowthRate                   234 non-null    float64
# ...

# %%
# Detectar columnas numéricas que representan años
year_cols = [col for col in df.columns if col.isdigit()]

# Derretir el dataframe usando solo esas columnas
df_long = df.melt(
    id_vars=[col for col in df.columns if col not in year_cols],
    value_vars=year_cols,
    var_name="Year",
    value_name="Population"
)

# Convertir Year a entero
df_long["Year"] = df_long["Year"].astype(int)

# Agrupar por año y sumar
df_total = df_long.groupby("Year", as_index=False)["Population"].sum().sort_values("Year")

print(df_total.head(8))
# Out:
#    Year  Population
# 0  1970     3694129
# 1  1980     4442407
# 2  1990     5314196
# 3  2000     6147055
# 4  2010     6983783
# 5  2015     7424808
# 6  2020     7839255
# 7  2022     7973413

# %%
#Agregar una fila para año 2025 y poblacion 8.3 billones
df_total = pd.concat([df_total, pd.DataFrame({"Year": [2025], "Population": [8300000]})], ignore_index=True)

# %%
df_total.head(10)
# Out:
#    Year  Population
# 0  1970     3694129
# 1  1980     4442407
# 2  1990     5314196
# 3  2000     6147055
# 4  2010     6983783
# 5  2015     7424808
# 6  2020     7839255
# 7  2022     7973413
# 8  2025     8300000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

# Escalamos la población a millones
plt.plot(df_total["Year"], df_total["Population"] / 1e6, marker='o', color='#004C97')

plt.title("Evolución de la población mundial", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Población total (millones)", fontsize=12)

# Mostrar números normales (no notación científica)
plt.ticklabel_format(axis='y', style='plain')

# Ajustar ticks para mostrar una cifra razonable (por ejemplo 3.0, 4.0, 5.0, etc.)
plt.yticks(range(3, 9))  # podés ajustarlo según tus datos

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#salvar csv 
df_total.to_csv('world_population_total.csv', index=False)
